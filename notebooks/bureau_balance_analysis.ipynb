# %% [markdown]
# # Bureau Balance Analysis
# -
# -
# ---

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
bureau_balance_df = pd.read_csv("../data/raw/bureau_balance.csv")
print(f"Shape of bureau_balance_df: {bureau_balance_df.shape}")
bureau_balance_df.head()

# %% [markdown]
# ## 1. Review of the columns

# %% [markdown]
# - `AMT_ANNUITY` - Annuity of the Credit Bureau credit
# - `SK_BUREAU_ID` - Recoded ID of Credit Bureau credit (unique coding for each application) - __use this to join to CREDIT_BUREAU table__
# - `MONTHS_BALANCE` - Month of balance relative to application date (-1 means the freshest balance date),time only relative to the application
# -
