# %% [markdown]
# # Univariate analysis of application (loan) data

# %% [markdown]
# ## 0. Import Libraries

# %%
import pandas as pd
import numpy as np

import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent
SRC_PATH = PROJECT_ROOT / 'src'

if str(SRC_PATH) not in sys.path:
    sys.path.insert(0, str(SRC_PATH))

from eda_module import plot_quantitative_distribution, quantitative_vs_binary
